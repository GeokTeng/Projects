# %% [markdown]
# # About this notebook:
#
# - We are creating dictionaries for subsequent article labelling.
# - We downloaded the MeSH terms data from the website [US National Library of Medicine (NLM)](https://www.nlm.nih.gov/databases/download/mesh.html)
#
# **About MeSH**
# - The Medical Subject Headings (MeSH) thesaurus is a controlled and hierarchically-organized vocabulary produced by the National Library of Medicine.
# - It is used for indexing, cataloging, and searching of biomedical and health-related information.
# - MeSH includes the subject headings appearing in MEDLINE/PubMed, the NLM Catalog, and other NLM databases.

# %%
# Import libaries
import numpy as np 
import pandas as pd 

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

#Visualisation:
import seaborn               as sns
import matplotlib.pyplot     as plt
sns.set_theme(style="whitegrid")

# %% [markdown]
# # Preparing MeSH terms dataframe

# %%
# Read the data from the BIN file
with open('mtrees2022.bin', 'r') as f:
    lines = f.readlines()

# Create a list of dictionaries with the Term and term_full_ID for each line
data = []
for line in lines:
    term, term_full_ID = line.strip().split(';')
    data.append({'Term': term, 'term_full_ID': term_full_ID})

print(len(data))
# Out:
# 62317

# %%
# Create a Pandas dataframe from the list of dictionaries
df = pd.DataFrame(data)

# Print the dataframe
print(df)
# Out:
#                         Term     term_full_ID
# 0               Body Regions              A01
# 1         Anatomic Landmarks          A01.111
# 2                     Breast          A01.236
# 3      Mammary Glands, Human      A01.236.249
# 4                    Nipples      A01.236.500
# ...                      ...              ...
# 62312              North Sea  Z01.756.092.650
# 62313              Black Sea      Z01.756.217
# 62314           Indian Ocean      Z01.756.342
# 62315      Mediterranean Sea      Z01.756.592
# 62316          Pacific Ocean      Z01.756.700
#
# [62317 rows x 2 columns]

# %%
df['Root_term'] = df['term_full_ID'].apply(lambda x: x[0])
df.head()
# Out:
#                     Term term_full_ID Root_term
# 0           Body Regions          A01         A
# 1     Anatomic Landmarks      A01.111         A
# 2                 Breast      A01.236         A
# 3  Mammary Glands, Human  A01.236.249         A
# 4                Nipples  A01.236.500         A

# %%
disease_df = df.copy()

# %%
disease_df['Root_term'].unique()
disease_df['Root_term'].nunique()
# Out:
# array(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M',
#        'N', 'V', 'Z'], dtype=object)
# 16

# %%
disease_df = disease_df.loc[disease_df['Root_term']=='C',:]
disease_df
# Out:
#                              Term     term_full_ID Root_term
# 8513                   Infections              C01         C
# 8514           Aneurysm, Infected          C01.069         C
# 8515        Arthritis, Infectious          C01.100         C
# 8516          Arthritis, Reactive      C01.100.500         C
# 8517      Asymptomatic Infections          C01.125         C
# ...                           ...              ...       ...
# 21258   Eye Injuries, Penetrating      C26.986.450         C
# 21259  Head Injuries, Penetrating      C26.986.500         C
# 21260             Wounds, Gunshot      C26.986.900         C
# 21261                Wounds, Stab      C26.986.950         C
# 21262        Needlestick Injuries  C26.986.950.500         C
#
# [12750 rows x 3 columns]

# %%
disease_df['Pri_Disease_ID'] = disease_df['term_full_ID'].apply(lambda x: x[:3])
disease_df['Sec_Disease_ID'] = disease_df['term_full_ID'].apply(lambda x: x[:7])

# %%
disease_df['Sec_Disease_ID']
# Out:
# 8513         C01
# 8514     C01.069
# 8515     C01.100
# 8516     C01.100
# 8517     C01.125
#           ...
# 21258    C26.986
# 21259    C26.986
# 21260    C26.986
# 21261    C26.986
# 21262    C26.986
# Name: Sec_Disease_ID, Length: 12750, dtype: object

# %%
disease_df['Pri_Disease_ID'].unique()
disease_df['Pri_Disease_ID'].nunique()
# Out:
# array(['C01', 'C04', 'C05', 'C06', 'C07', 'C08', 'C09', 'C10', 'C11',
#        'C12', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21',
#        'C22', 'C23', 'C24', 'C25', 'C26'], dtype=object)
# 23

# %%
disease_df.drop(columns="Root_term",inplace=True)
disease_df
# Out:
#                              Term     term_full_ID Pri_Disease_ID  \
# 8513                   Infections              C01            C01
# 8514           Aneurysm, Infected          C01.069            C01
# 8515        Arthritis, Infectious          C01.100            C01
# 8516          Arthritis, Reactive      C01.100.500            C01
# 8517      Asymptomatic Infections          C01.125            C01
# ...                           ...              ...            ...
# 21258   Eye Injuries, Penetrating      C26.986.450            C26
# 21259  Head Injuries, Penetrating      C26.986.500            C26
# 21260             Wounds, Gunshot      C26.986.900            C26
# 21261                Wounds, Stab      C26.986.950            C26
# 21262        Needlestick Injuries  C26.986.950.500            C26
#
#       Sec_Disease_ID
# 8513             C01
# 8514         C01.069
# 8515         C01.100
# 8516         C01.100
# 8517         C01.125
# ...              ...
# ...

# %% [markdown]
# # Analysing the Mesh Terms (EDA)

# %% [markdown]
# ## Primary disease ID & Associate Primary disease types

# %%
# key = Primary disease ID
# value = Associate Primary disease type
_df = disease_df.loc[(disease_df["term_full_ID"].str.len())<4,:]
Pri_disease_dict = dict(zip(_df['term_full_ID'], _df['Term']))
Pri_disease_dict
# Out:
# {'C01': 'Infections',
#  'C04': 'Neoplasms',
#  'C05': 'Musculoskeletal Diseases',
#  'C06': 'Digestive System Diseases',
#  'C07': 'Stomatognathic Diseases',
#  'C08': 'Respiratory Tract Diseases',
#  'C09': 'Otorhinolaryngologic Diseases',
#  'C10': 'Nervous System Diseases',
#  'C11': 'Eye Diseases',
#  'C12': 'Urogenital Diseases',
#  'C14': 'Cardiovascular Diseases',
#  'C15': 'Hemic and Lymphatic Diseases',
#  'C16': 'Congenital, Hereditary, and Neonatal Diseases and Abnormalities',
#  'C17': 'Skin and Connective Tissue Diseases',
#  'C18': 'Nutritional and Metabolic Diseases',
#  'C19': 'Endocrine System Diseases',
#  'C20': 'Immune System Diseases',
#  'C21': 'Disorders of Environmental Origin',
#  'C22': 'Animal Diseases',
#  'C23': 'Pathological Conditions, Signs and Symptoms',
#  'C24': 'Occupational Diseases',
#  'C25': 'Chemically-Induced Disorders',
#  'C26': 'Wounds and Injuries'}

# %%
print(f"Length of Pri_disease_dict: {len(Pri_disease_dict)}")
# Out:
# Length of Pri_disease_dict: 23

# %%
disease_df['Pri_disease_term'] = disease_df['Pri_Disease_ID'].map(Pri_disease_dict)
disease_df
# Out:
#                              Term     term_full_ID Pri_Disease_ID  \
# 8513                   Infections              C01            C01
# 8514           Aneurysm, Infected          C01.069            C01
# 8515        Arthritis, Infectious          C01.100            C01
# 8516          Arthritis, Reactive      C01.100.500            C01
# 8517      Asymptomatic Infections          C01.125            C01
# ...                           ...              ...            ...
# 21258   Eye Injuries, Penetrating      C26.986.450            C26
# 21259  Head Injuries, Penetrating      C26.986.500            C26
# 21260             Wounds, Gunshot      C26.986.900            C26
# 21261                Wounds, Stab      C26.986.950            C26
# 21262        Needlestick Injuries  C26.986.950.500            C26
#
#       Sec_Disease_ID     Pri_disease_term
# 8513             C01           Infections
# 8514         C01.069           Infections
# 8515         C01.100           Infections
# ...

# %% [markdown]
# ### Diseases under each Pri_Disease_ID

# %%
_s = disease_df.groupby('Pri_Disease_ID').size()
print("Number of diseases under each Pri_Disease_ID")
_s
print(f"\nStatistical description of Primary term ID: \n{_s.describe()}")
# Out:
# Number of diseases under each Pri_Disease_ID
# Pri_Disease_ID
# C01    1387
# C04    1055
# C05     528
# C06     494
# C07     291
# C08     382
# C09     142
# C10    1474
# C11     356
# C12    1101
# C14     679
# C15     391
# C16    1183
# C17     541
# C18     620
# C19     215
# C20     269
# C21       5
# C22     143
# C23    1034
# C24      24
# C25     127
# C26     309
# dtype: int64
# Statistical description of Primary term ID:
# count      23.000000
# mean      554.347826
# std       440.297173
# min         5.000000
# 25%       242.000000
# 50%       391.000000
# 75%       856.500000
# max      1474.000000
# dtype: float64

# %%
sns.histplot(_s, bins=20)
plt.title("Number of diseases under each Pri_Disease_ID");

# %% [markdown]
# ## Secondary disease ID & Associate Secondary disease types

# %%
length = disease_df["term_full_ID"].str.len()

disease_df.loc[(length>3)&(length<8),:]
# Out:
#                                    Term term_full_ID Pri_Disease_ID  \
# 8514                 Aneurysm, Infected      C01.069            C01
# 8515              Arthritis, Infectious      C01.100            C01
# 8517            Asymptomatic Infections      C01.125            C01
# 8518   Bacterial Infections and Mycoses      C01.150            C01
# 8876          Bone Diseases, Infectious      C01.160            C01
# ...                                 ...          ...            ...
# 21243     Tympanic Membrane Perforation      C26.930            C26
# 21244          Vascular System Injuries      C26.940            C26
# 21245              War-Related Injuries      C26.946            C26
# 21246            Wounds, Nonpenetrating      C26.974            C26
# 21255               Wounds, Penetrating      C26.986            C26
#
#       Sec_Disease_ID     Pri_disease_term
# 8514         C01.069           Infections
# 8515         C01.100           Infections
# ...

# %%
#dictionary refelecting each key and the associate disease as value
_df = disease_df.loc[(length>3)&(length<8),:]
Sec_disease_dict = dict(zip(_df['Sec_Disease_ID'], _df['Term']))
Sec_disease_dict
# Out:
# {'C01.069': 'Aneurysm, Infected',
#  'C01.100': 'Arthritis, Infectious',
#  'C01.125': 'Asymptomatic Infections',
#  'C01.150': 'Bacterial Infections and Mycoses',
#  'C01.160': 'Bone Diseases, Infectious',
#  'C01.190': 'Cardiovascular Infections',
#  'C01.195': 'Catheter-Related Infections',
#  'C01.207': 'Central Nervous System Infections',
#  'C01.218': 'Coinfection',
#  'C01.221': 'Communicable Diseases',
#  'C01.234': 'Community-Acquired Infections',
#  'C01.248': 'Cross Infection',
#  'C01.375': 'Eye Infections',
#  'C01.392': 'Focal Infection',
#  'C01.408': 'Gingivitis',
#  'C01.436': 'Hepatitis, Animal',
#  'C01.463': 'Intraabdominal Infections',
#  'C01.503': 'Laboratory Infection',
#  'C01.550': 'Latent Infection',
#  'C01.597': 'Opportunistic Infections',
#  'C01.610': 'Parasitic Diseases',
#  'C01.635': 'Pelvic Infection',
#  'C01.645': 'Persistent Infection',
#  'C01.655': 'Poult Enteritis Mortality Syndrome',
#  'C01.674': 'Pregnancy Complications, Infectious',
# ...

# %%
print(f"Length of Sec_disease_dict: {len(Sec_disease_dict)}")
# Out:
# Length of Sec_disease_dict: 310

# %%
disease_df['Sec_disease_term'] = disease_df['Sec_Disease_ID'].map(Sec_disease_dict)
disease_df
# Out:
#                              Term     term_full_ID Pri_Disease_ID  \
# 8513                   Infections              C01            C01
# 8514           Aneurysm, Infected          C01.069            C01
# 8515        Arthritis, Infectious          C01.100            C01
# 8516          Arthritis, Reactive      C01.100.500            C01
# 8517      Asymptomatic Infections          C01.125            C01
# ...                           ...              ...            ...
# 21258   Eye Injuries, Penetrating      C26.986.450            C26
# 21259  Head Injuries, Penetrating      C26.986.500            C26
# 21260             Wounds, Gunshot      C26.986.900            C26
# 21261                Wounds, Stab      C26.986.950            C26
# 21262        Needlestick Injuries  C26.986.950.500            C26
#
#       Sec_Disease_ID     Pri_disease_term         Sec_disease_term
# 8513             C01           Infections                      NaN
# ...

# %%
disease_df[disease_df["Term"]=='22q11 Deletion Syndrome']
# Out:
#                           Term         term_full_ID Pri_Disease_ID  \
# 11390  22q11 Deletion Syndrome      C05.660.207.103            C05
# 15726  22q11 Deletion Syndrome      C14.240.400.021            C14
# 15914  22q11 Deletion Syndrome      C14.280.400.044            C14
# 16707  22q11 Deletion Syndrome      C15.604.451.249            C15
# 16797  22q11 Deletion Syndrome      C16.131.077.019            C16
# 16881  22q11 Deletion Syndrome  C16.131.240.400.021            C16
# 16953  22q11 Deletion Syndrome      C16.131.260.019            C16
# 17008  22q11 Deletion Syndrome      C16.131.482.249            C16
# 17016  22q11 Deletion Syndrome  C16.131.621.207.103            C16
# 17334  22q11 Deletion Syndrome      C16.320.180.019            C16
# 19294  22q11 Deletion Syndrome      C19.642.482.500            C19
#
#       Sec_Disease_ID                                   Pri_disease_term  \
# 11390        C05.660                           Musculoskeletal Diseases
# ...

# %% [markdown]
# ### Diseases under each Sec_Disease_ID

# %%
print("Number of diseases under each Sec_Disease_ID:")
disease_df.groupby('Sec_Disease_ID').size()
_s = disease_df.groupby('Sec_Disease_ID').size()
print(f"\nStatistical description of Secondary term ID: \n{_s.describe()}")
# Out:
# Number of diseases under each Sec_Disease_ID:
# Sec_Disease_ID
# C01          1
# C01.069      1
# C01.100      2
# C01.125      1
# C01.150    358
#           ...
# C26.930      1
# C26.940      1
# C26.946      1
# C26.974      9
# C26.986      8
# Length: 333, dtype: int64
# Statistical description of Secondary term ID:
# count    333.000000
# mean      38.288288
# std       97.498599
# min        1.000000
# 25%        1.000000
# 50%        4.000000
# 75%       24.000000
# max      642.000000
# dtype: float64

# %%
sns.histplot(_s)
plt.title("Number of diseases under each Sec_Disease_ID");

# %% [markdown]
# ### Secondary terms with multiple Sec_disease ID

# %%
# Create a new dictionary to store the keys grouped by their values
grouped_dict = {}

# Iterate over the keys and values of the original dictionary
for key, value in Sec_disease_dict.items():
    
    # Use setdefault method to add value to the list of keys with the same value
    grouped_dict.setdefault(value, []).append(key)

# %%
# Iterate over the keys and values of the grouped dictionary
print("Secondary terms with multiple Sec_disease ID:\n\n")
for key, value in grouped_dict.items():
    
    # Print the keys with the same value
    if len(value) > 1:
        print("Disease:", key, "\n -----> ID:", value, "\n ")
# Out:
# Secondary terms with multiple Sec_disease ID:
#
#
# Disease: Cardiovascular Infections
#  -----> ID: ['C01.190', 'C14.260']
#
# Disease: Eye Infections
#  -----> ID: ['C01.375', 'C11.294']
#
# Disease: Hepatitis, Animal
#  -----> ID: ['C01.436', 'C22.467']
#
# Disease: Laboratory Infection
#  -----> ID: ['C01.503', 'C24.506']
#
# Disease: Respiratory Tract Infections
#  -----> ID: ['C01.748', 'C08.730']
#
# Disease: Zoonoses
#  -----> ID: ['C01.973', 'C22.969']
#
# Disease: Jaw Diseases
#  -----> ID: ['C05.500', 'C07.320']
#
# Disease: Pharyngeal Diseases
#  -----> ID: ['C07.550', 'C09.775']
#
# Disease: Ciliary Motility Disorders
#  -----> ID: ['C08.200', 'C09.150']
#
# Disease: Laryngeal Diseases
#  -----> ID: ['C08.360', 'C09.400']
#
# Disease: Nose Diseases
#  -----> ID: ['C08.460', 'C09.603']
#
# Disease: Trauma, Nervous System
#  -----> ID: ['C10.900', 'C26.915']

# %% [markdown]
# ## Creating the important dictionary
#
# Each unique term forms the 'key', with its value containins a list of secondary ids

# %% [markdown]
# ### Sec_term

# %%
sec_term_dict = disease_df.groupby('Term')['Sec_Disease_ID'].apply(list).to_dict()
len(sec_term_dict)
# Out:
# 4933

# %%
disease_df['Term'].nunique()
# Out:
# 4933

# %%
sec_term_dict
# Out:
# {'22q11 Deletion Syndrome': ['C05.660',
#   'C14.240',
#   'C14.280',
#   'C15.604',
#   'C16.131',
#   'C16.131',
#   'C16.131',
#   'C16.131',
#   'C16.131',
#   'C16.320',
#   'C19.642'],
#  '46, XX Disorders of Sex Development': ['C12.050',
#   'C12.200',
#   'C12.800',
#   'C16.131',
#   'C19.391'],
#  '46, XX Testicular Disorders of Sex Development': ['C12.050',
#   'C12.200',
#   'C12.800',
#   'C16.131',
#   'C19.391'],
#  'ACTH Syndrome, Ectopic': ['C04.730'],
#  'ACTH-Secreting Pituitary Adenoma': ['C04.557',
#   'C04.588',
#   'C10.228',
#   'C19.344',
#   'C19.700'],
#  'AIDS Arteritis, Central Nervous System': ['C01.221',
#   'C01.221',
#   'C01.778',
#   'C01.925',
#   'C01.925',
#   'C10.114',
#   'C10.228',
#   'C12.100',
#   'C14.907',
#   'C14.907',
#   'C14.907',
#   'C20.673'],
#  'AIDS Dementia Complex': ['C01.221',
#   'C01.221',
#   'C01.778',
#   'C01.925',
#   'C01.925',
#   'C10.228',
#   'C12.100',
#   'C20.673'],
# ...

# %%
#remove duplicate values in each key
for key, value in sec_term_dict.items():
    sec_term_dict[key]=set(value)

# %% [markdown]
# ### Pri_term

# %%
pri_term_dict = disease_df.groupby('Term')['Pri_Disease_ID'].apply(list).to_dict()
len(pri_term_dict)
# Out:
# 4933

# %%
pri_term_dict
# Out:
# {'22q11 Deletion Syndrome': ['C05',
#   'C14',
#   'C14',
#   'C15',
#   'C16',
#   'C16',
#   'C16',
#   'C16',
#   'C16',
#   'C16',
#   'C19'],
#  '46, XX Disorders of Sex Development': ['C12', 'C12', 'C12', 'C16', 'C19'],
#  '46, XX Testicular Disorders of Sex Development': ['C12',
#   'C12',
#   'C12',
#   'C16',
#   'C19'],
#  'ACTH Syndrome, Ectopic': ['C04'],
#  'ACTH-Secreting Pituitary Adenoma': ['C04', 'C04', 'C10', 'C19', 'C19'],
#  'AIDS Arteritis, Central Nervous System': ['C01',
#   'C01',
#   'C01',
#   'C01',
#   'C01',
#   'C10',
#   'C10',
#   'C12',
#   'C14',
#   'C14',
#   'C14',
#   'C20'],
#  'AIDS Dementia Complex': ['C01',
#   'C01',
#   'C01',
#   'C01',
#   'C01',
#   'C10',
#   'C12',
#   'C20'],
#  'AIDS-Associated Nephropathy': ['C01',
#   'C01',
#   'C01',
#   'C01',
#   'C01',
#   'C12',
#   'C12',
#   'C12',
#   'C12',
#   'C20'],
#  'AIDS-Related Complex': ['C01',
#   'C01',
#   'C01',
#   'C01',
#   'C01',
#   'C01',
#   'C12',
#   'C20'],
# ...

# %%
#remove duplicate values in each key
for key, value in pri_term_dict.items():
    pri_term_dict[key]=set(value)

# %%
pri_term_dict
# Out:
# {'22q11 Deletion Syndrome': {'C05', 'C14', 'C15', 'C16', 'C19'},
#  '46, XX Disorders of Sex Development': {'C12', 'C16', 'C19'},
#  '46, XX Testicular Disorders of Sex Development': {'C12', 'C16', 'C19'},
#  'ACTH Syndrome, Ectopic': {'C04'},
#  'ACTH-Secreting Pituitary Adenoma': {'C04', 'C10', 'C19'},
#  'AIDS Arteritis, Central Nervous System': {'C01', 'C10', 'C12', 'C14', 'C20'},
#  'AIDS Dementia Complex': {'C01', 'C10', 'C12', 'C20'},
#  'AIDS-Associated Nephropathy': {'C01', 'C12', 'C20'},
#  'AIDS-Related Complex': {'C01', 'C12', 'C20'},
#  'AIDS-Related Opportunistic Infections': {'C01', 'C20'},
#  'Abdomen, Acute': {'C23'},
#  'Abdominal Abscess': {'C01'},
#  'Abdominal Injuries': {'C26'},
#  'Abdominal Neoplasms': {'C04'},
#  'Abdominal Pain': {'C23'},
#  'Abducens Nerve Diseases': {'C10'},
#  'Abducens Nerve Injury': {'C10', 'C26'},
#  'Aberrant Crypt Foci': {'C04'},
#  'Abetalipoproteinemia': {'C16', 'C18'},
#  'Abnormal Karyotype': {'C23'},
# ...

# %% [markdown]
# ## Export disease_df

# %%
disease_df
# Out:
#                              Term     term_full_ID Pri_Disease_ID  \
# 8513                   Infections              C01            C01
# 8514           Aneurysm, Infected          C01.069            C01
# 8515        Arthritis, Infectious          C01.100            C01
# 8516          Arthritis, Reactive      C01.100.500            C01
# 8517      Asymptomatic Infections          C01.125            C01
# ...                           ...              ...            ...
# 21258   Eye Injuries, Penetrating      C26.986.450            C26
# 21259  Head Injuries, Penetrating      C26.986.500            C26
# 21260             Wounds, Gunshot      C26.986.900            C26
# 21261                Wounds, Stab      C26.986.950            C26
# 21262        Needlestick Injuries  C26.986.950.500            C26
#
#       Sec_Disease_ID     Pri_disease_term         Sec_disease_term
# 8513             C01           Infections                      NaN
# ...

# %%
disease_df.to_csv("MeSH_terms.csv",index=False)

# %%
disease_df
# Out:
#                              Term     term_full_ID Pri_Disease_ID  \
# 8513                   Infections              C01            C01
# 8514           Aneurysm, Infected          C01.069            C01
# 8515        Arthritis, Infectious          C01.100            C01
# 8516          Arthritis, Reactive      C01.100.500            C01
# 8517      Asymptomatic Infections          C01.125            C01
# ...                           ...              ...            ...
# 21258   Eye Injuries, Penetrating      C26.986.450            C26
# 21259  Head Injuries, Penetrating      C26.986.500            C26
# 21260             Wounds, Gunshot      C26.986.900            C26
# 21261                Wounds, Stab      C26.986.950            C26
# 21262        Needlestick Injuries  C26.986.950.500            C26
#
#       Sec_Disease_ID     Pri_disease_term         Sec_disease_term
# 8513             C01           Infections                      NaN
# ...

# %% [markdown]
# # Analysing the Pri term & Sec terms

# %%
terms_df = disease_df.loc[:,['Pri_Disease_ID', 'Sec_Disease_ID']]
terms_df.drop_duplicates(inplace=True)
terms_df.drop(terms_df[terms_df['Pri_Disease_ID'] == terms_df['Sec_Disease_ID']].index, inplace=True)

# %%
terms_df
# Out:
#       Pri_Disease_ID Sec_Disease_ID
# 8514             C01        C01.069
# 8515             C01        C01.100
# 8517             C01        C01.125
# 8518             C01        C01.150
# 8876             C01        C01.160
# ...              ...            ...
# 21243            C26        C26.930
# 21244            C26        C26.940
# 21245            C26        C26.946
# 21246            C26        C26.974
# 21255            C26        C26.986
#
# [310 rows x 2 columns]

# %%
print("Number of Secondary ID under each Primary ID:")
_s = terms_df.groupby('Pri_Disease_ID')['Sec_Disease_ID'].size()
_s
# Out:
# Number of Secondary ID under each Primary ID:
# Pri_Disease_ID
# C01    41
# C04    15
# C05    11
# C06     8
# C07     7
# C08    15
# C09     6
# C10    17
# C11    26
# C12     8
# C14     5
# C15     2
# C16     4
# C17     2
# C18     2
# C19    11
# C20    11
# C21     2
# C22    45
# C23     4
# C24    12
# C25     3
# C26    53
# Name: Sec_Disease_ID, dtype: int64

# %%
def annotation_fx(my_barchart):
    for each_bar in my_barchart.patches:
        plt.annotate(format(each_bar.get_height(), '.0f'),
                       (each_bar.get_x() + each_bar.get_width() / 2,
                        each_bar.get_height()), ha='center', va='center',
                       size=10, xytext=(0, 8),
                       textcoords='offset points')

# %%
fig = plt.figure(figsize=(10,8))

_s.sort_values().plot(kind='barh')

# add annotations to the bars
ax = _s.sort_values().plot(kind='barh')
for i, v in enumerate(_s.sort_values()):
    ax.text(v + 0.5, i - 0.1, str(v), color='black')

# set the Y-tick labels using the label_dict
ax.set_yticklabels([Pri_disease_dict[x] for x in _s.index])
plt.title("Number of Secondary ID under each Primary ID",fontsize=16)
plt.ylabel("Primary ID");
